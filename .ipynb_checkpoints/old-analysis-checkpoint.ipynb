# %%
import numpy as np
import pandas as pd

from numpy import genfromtxt
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import KFold
import lightgbm as lgb
from sklearn.metrics.pairwise import nan_euclidean_distances
from sklearn import tree
from sklearn.svm import SVC
from mpl_toolkits.basemap import Basemap
from mpl_toolkits.mplot3d import Axes3D


from sklearn.decomposition import PCA
from base64 import encode
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
from sklearn import compose
from sklearn.pipeline import FeatureUnion
from sklearn.metrics import mean_absolute_error

import copy


from ax.plot.contour import plot_contour
from ax.plot.trace import optimization_trace_single_method
from ax import optimize
from ax.utils.notebook.plotting import render, init_notebook_plotting
# %matplotlib inline

rng = 0

test_values = pd.read_csv("./test-set-values.csv")
train_values = pd.read_csv("./training-set-values.csv")
train_labels = pd.read_csv("./training-set-labels.csv")

# %%
print("columns:")
print(train_values.columns.values)
print()
print(train_values.info())
# Out:
# columns:
# ['id' 'amount_tsh' 'date_recorded' 'funder' 'gps_height' 'installer'
#  'longitude' 'latitude' 'wpt_name' 'num_private' 'basin' 'subvillage'
#  'region' 'region_code' 'district_code' 'lga' 'ward' 'population'
#  'public_meeting' 'recorded_by' 'scheme_management' 'scheme_name' 'permit'
#  'construction_year' 'extraction_type' 'extraction_type_group'
#  'extraction_type_class' 'management' 'management_group' 'payment'
#  'payment_type' 'water_quality' 'quality_group' 'quantity'
#  'quantity_group' 'source' 'source_type' 'source_class' 'waterpoint_type'
#  'waterpoint_type_group']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     59400 non-null  int64
#  1   amount_tsh             59400 non-null  float64
#  2   date_recorded          59400 non-null  object
#  3   funder                 55765 non-null  object
#  4   gps_height             59400 non-null  int64
#  5   installer              55745 non-null  object
#  6   longitude              59400 non-null  float64
#  7   latitude               59400 non-null  float64
#  8   wpt_name               59400 non-null  object
#  9   num_private            59400 non-null  int64
#  10  basin                  59400 non-null  object
#  11  subvillage             59029 non-null  object
#  12  region                 59400 non-null  object
#  13  region_code            59400 non-null  int64
#  14  district_code          59400 non-null  int64
#  15  lga                    59400 non-null  object
#  16  ward                   59400 non-null  object
#  17  population             59400 non-null  int64
#  18  public_meeting         56066 non-null  object
#  19  recorded_by            59400 non-null  object
#  20  scheme_management      55523 non-null  object
#  21  scheme_name            31234 non-null  object
#  22  permit                 56344 non-null  object
#  23  construction_year      59400 non-null  int64
#  24  extraction_type        59400 non-null  object
#  25  extraction_type_group  59400 non-null  object
#  26  extraction_type_class  59400 non-null  object
#  27  management             59400 non-null  object
#  28  management_group       59400 non-null  object
#  29  payment                59400 non-null  object
#  30  payment_type           59400 non-null  object
#  31  water_quality          59400 non-null  object
#  32  quality_group          59400 non-null  object
#  33  quantity               59400 non-null  object
#  34  quantity_group         59400 non-null  object
#  35  source                 59400 non-null  object
#  36  source_type            59400 non-null  object
#  37  source_class           59400 non-null  object
#  38  waterpoint_type        59400 non-null  object
#  39  waterpoint_type_group  59400 non-null  object
# dtypes: float64(3), int64(7), object(30)
# memory usage: 18.1+ MB
# None

# %%
train_values.iloc[:, :20].describe(include='all')
# Out:
#                   id     amount_tsh date_recorded                  funder  \
# count   59400.000000   59400.000000         59400                   55765
# unique           NaN            NaN           356                    1897
# top              NaN            NaN    2011-03-15  Government Of Tanzania
# freq             NaN            NaN           572                    9084
# mean    37115.131768     317.650385           NaN                     NaN
# std     21453.128371    2997.574558           NaN                     NaN
# min         0.000000       0.000000           NaN                     NaN
# 25%     18519.750000       0.000000           NaN                     NaN
# 50%     37061.500000       0.000000           NaN                     NaN
# 75%     55656.500000      20.000000           NaN                     NaN
# max     74247.000000  350000.000000           NaN                     NaN
#
#           gps_height installer     longitude      latitude wpt_name  \
# count   59400.000000     55745  59400.000000  5.940000e+04    59400
# unique           NaN      2145           NaN           NaN    37400
# top              NaN       DWE           NaN           NaN     none
# freq             NaN     17402           NaN           NaN     3563
# mean      668.297239       NaN     34.077427 -5.706033e+00      NaN
# std       693.116350       NaN      6.567432  2.946019e+00      NaN
# min       -90.000000       NaN      0.000000 -1.164944e+01      NaN
# 25%         0.000000       NaN     33.090347 -8.540621e+00      NaN
# 50%       369.000000       NaN     34.908743 -5.021597e+00      NaN
# 75%      1319.250000       NaN     37.178387 -3.326156e+00      NaN
# max      2770.000000       NaN     40.345193 -2.000000e-08      NaN
#
#          num_private          basin subvillage  region   region_code  \
# count   59400.000000          59400      59029   59400  59400.000000
# unique           NaN              9      19287      21           NaN
# top              NaN  Lake Victoria   Madukani  Iringa           NaN
# freq             NaN          10248        508    5294           NaN
# mean        0.474141            NaN        NaN     NaN     15.297003
# std        12.236230            NaN        NaN     NaN     17.587406
# min         0.000000            NaN        NaN     NaN      1.000000
# 25%         0.000000            NaN        NaN     NaN      5.000000
# 50%         0.000000            NaN        NaN     NaN     12.000000
# 75%         0.000000            NaN        NaN     NaN     17.000000
# max      1776.000000            NaN        NaN     NaN     99.000000
#
#         district_code     lga   ward    population public_meeting  \
# count    59400.000000   59400  59400  59400.000000          56066
# unique            NaN     125   2092           NaN              2
# top               NaN  Njombe  Igosi           NaN           True
# freq              NaN    2503    307           NaN          51011
# mean         5.629747     NaN    NaN    179.909983            NaN
# std          9.633649     NaN    NaN    471.482176            NaN
# min          0.000000     NaN    NaN      0.000000            NaN
# 25%          2.000000     NaN    NaN      0.000000            NaN
# 50%          3.000000     NaN    NaN     25.000000            NaN
# 75%          5.000000     NaN    NaN    215.000000            NaN
# max         80.000000     NaN    NaN  30500.000000            NaN
#
#                     recorded_by
# count                     59400
# unique                        1
# top     GeoData Consultants Ltd
# freq                      59400
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN

# %%
train_values.iloc[:, 21:].describe(include='all')
# Out:
#        scheme_name permit  construction_year extraction_type  \
# count        31234  56344       59400.000000           59400
# unique        2696      2                NaN              18
# top              K   True                NaN         gravity
# freq           682  38852                NaN           26780
# mean           NaN    NaN        1300.652475             NaN
# std            NaN    NaN         951.620547             NaN
# min            NaN    NaN           0.000000             NaN
# 25%            NaN    NaN           0.000000             NaN
# 50%            NaN    NaN        1986.000000             NaN
# 75%            NaN    NaN        2004.000000             NaN
# max            NaN    NaN        2013.000000             NaN
#
#        extraction_type_group extraction_type_class management  \
# count                  59400                 59400      59400
# unique                    13                     7         12
# top                  gravity               gravity        vwc
# freq                   26780                 26780      40507
# mean                     NaN                   NaN        NaN
# std                      NaN                   NaN        NaN
# min                      NaN                   NaN        NaN
# 25%                      NaN                   NaN        NaN
# 50%                      NaN                   NaN        NaN
# 75%                      NaN                   NaN        NaN
# max                      NaN                   NaN        NaN
#
#        management_group    payment payment_type water_quality quality_group  \
# count             59400      59400        59400         59400         59400
# unique                5          7            7             8             6
# top          user-group  never pay    never pay          soft          good
# freq              52490      25348        25348         50818         50818
# mean                NaN        NaN          NaN           NaN           NaN
# std                 NaN        NaN          NaN           NaN           NaN
# min                 NaN        NaN          NaN           NaN           NaN
# 25%                 NaN        NaN          NaN           NaN           NaN
# 50%                 NaN        NaN          NaN           NaN           NaN
# 75%                 NaN        NaN          NaN           NaN           NaN
# max                 NaN        NaN          NaN           NaN           NaN
#
#        quantity quantity_group  source source_type source_class  \
# count     59400          59400   59400       59400        59400
# unique        5              5      10           7            3
# top      enough         enough  spring      spring  groundwater
# freq      33186          33186   17021       17021        45794
# mean        NaN            NaN     NaN         NaN          NaN
# std         NaN            NaN     NaN         NaN          NaN
# min         NaN            NaN     NaN         NaN          NaN
# 25%         NaN            NaN     NaN         NaN          NaN
# 50%         NaN            NaN     NaN         NaN          NaN
# 75%         NaN            NaN     NaN         NaN          NaN
# max         NaN            NaN     NaN         NaN          NaN
#
#            waterpoint_type waterpoint_type_group
# count                59400                 59400
# unique                   7                     6
# top     communal standpipe    communal standpipe
# freq                 28522                 34625
# mean                   NaN                   NaN
# std                    NaN                   NaN
# min                    NaN                   NaN
# 25%                    NaN                   NaN
# 50%                    NaN                   NaN
# 75%                    NaN                   NaN
# max                    NaN                   NaN

# %%
train_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            59400 non-null  int64
#  1   status_group  59400 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 928.2+ KB

# %%
d = {
    "funder": "string",
    "installer": "string",
    "wpt_name": "string",
    "basin": "string",
    "subvillage": "string",
    "region": "string",
    "lga": "string",
    "ward": "string",
    "public_meeting": "string",
    "recorded_by": "string",
    "scheme_management": "string",
    "scheme_name": "string",
    "permit": "string",
    "extraction_type": "string",
    "extraction_type_group": "string",
    "extraction_type_class": "string",
    "management": "string",
    "management_group": "string",
    "payment": "string",
    "payment_type": "string",
    "water_quality": "string",
    "quality_group": "string",
    "quantity": "string",
    "quantity_group": "string",
    "source": "string",
    "source_type": "string",
    "source_class": "string",
    "waterpoint_type": "string",
    "waterpoint_type_group": "string",
    "date_recorded":"string",
}
train_values= train_values.astype(d)
# train_values["date_recorded"] = pd.to_datetime(
#     train_values["date_recorded"],
#     infer_datetime_format=True
# )

train_labels.status_group = train_labels.status_group.astype('string')
train = train_values.merge(train_labels, on="id")
train_labels.drop('id',inplace=True,axis=True)

# %% [markdown]
# # Null and Nan checking

# %%
# print("any nulls in train_values?")
# print(pd.isnull(train_values).any()[lambda x: x == True])
# print()
print("any NANs in train_values?")
print(pd.isna(train_values).any()[lambda x:x == True])
# Out:
# any nulls in train_values?
# funder               True
# installer            True
# subvillage           True
# public_meeting       True
# scheme_management    True
# scheme_name          True
# permit               True
# dtype: bool
#
# any NANs in train_values?
# funder               True
# installer            True
# subvillage           True
# public_meeting       True
# scheme_management    True
# scheme_name          True
# permit               True
# dtype: bool

# %% [markdown]
# There are alot of "0" strings around the features, they will be imputed to be "Unknown" just like the Nans.

# %% [markdown]
# # Checking correlations between numerical features

# %% [markdown]
# # Showing Values:

# %%
train_values.iloc[:, :20].head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name                    basin  \
# 0  34.938093  -9.856322                  none               Lake Nyasa
# 1  34.698766  -2.147466              Zahanati            Lake Victoria
# 2  37.460664  -3.821329           Kwa Mahundi                  Pangani
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu  Ruvuma / Southern Coast
# 4  31.130847  -1.825359               Shuleni            Lake Victoria
#
#    subvillage   region  region_code  district_code        lga        ward  \
# 0    Mnyusi B   Iringa           11              5     Ludewa    Mundindi
# 1     Nyamara     Mara           20              2  Serengeti       Natta
# 2     Majengo  Manyara           21              4  Simanjiro     Ngorika
# 3  Mahakamani   Mtwara           90             63   Nanyumbu    Nanyumbu
# 4  Kyanyamisa   Kagera           18              1    Karagwe  Nyakasimbi
#
#    population public_meeting              recorded_by scheme_management
# 0         109           True  GeoData Consultants Ltd               VWC
# 1         280        Unknown  GeoData Consultants Ltd             Other
# 2         250           True  GeoData Consultants Ltd               VWC
# 3          58           True  GeoData Consultants Ltd               VWC
# 4           0           True  GeoData Consultants Ltd           Unknown

# %%
train_values.iloc[:, 21:40].head()
# Out:
#   permit  construction_year extraction_type extraction_type_group  \
# 0  False               1999         gravity               gravity
# 1   True               2010         gravity               gravity
# 2   True               2009         gravity               gravity
# 3   True               1986     submersible           submersible
# 4   True                  0         gravity               gravity
#
#   extraction_type_class management management_group         payment  \
# 0               gravity        vwc       user-group    pay annually
# 1               gravity        wug       user-group       never pay
# 2               gravity        vwc       user-group  pay per bucket
# 3           submersible        vwc       user-group       never pay
# 4               gravity      other            other       never pay
#
#   payment_type water_quality quality_group      quantity quantity_group  \
# 0     annually          soft          good        enough         enough
# 1    never pay          soft          good  insufficient   insufficient
# 2   per bucket          soft          good        enough         enough
# 3    never pay          soft          good           dry            dry
# 4    never pay          soft          good      seasonal       seasonal
#
#                  source           source_type source_class  \
# 0                spring                spring  groundwater
# 1  rainwater harvesting  rainwater harvesting      surface
# 2                   dam                   dam      surface
# 3           machine dbh              borehole  groundwater
# 4  rainwater harvesting  rainwater harvesting      surface
#
#                waterpoint_type waterpoint_type_group
# 0           communal standpipe    communal standpipe
# 1           communal standpipe    communal standpipe
# 2  communal standpipe multiple    communal standpipe
# 3  communal standpipe multiple    communal standpipe
# 4           communal standpipe    communal standpipe

# %%
train_values['num_private'].value_counts()
# Out:
# 0       58643
# 6          81
# 1          73
# 5          46
# 8          46
#         ...
# 42          1
# 23          1
# 136         1
# 698         1
# 1402        1
# Name: num_private, Length: 65, dtype: int64

# %%
train_values['num_private'].unique()
# Out:
# array([   0,   39,    5,   45,    6,    3,  698,   32,   15,    7,   25,
#         102,    1,   93,   14,   34,  120,   17,  213,   47,    8,   41,
#          80,  141,   20,   35,  131,    4,   22,   11,   87,   61,   65,
#         136,    2,  180,   38,   62,    9,   16,   23,   42,   24,   12,
#         668,  672,   58,  150,  280,  160,   50, 1776,   30,   27,   10,
#          94,   26,  450,  240,  755,   60,  111,  300,   55, 1402])

# %% [markdown]
# ### DISCLAIMER: I do not know what is 'num_private' for.

# %% [markdown]
# There are alot of "0" strings around the features, they will be imputed to be "Unknown" just like the nulls and Nans.

# %%
imputer = SimpleImputer(missing_values="0",fill_value="unknown",strategy='constant')
temp = imputer.fit_transform(train_values)
train_values= pd.DataFrame(temp ,columns=train_values.columns)

# %%
print("Count of Unique dates recorded: "+str(len(train_values.date_recorded.unique())))
print()
print(train_values.date_recorded.value_counts().head(20))
# Out:
# Count of Unique dates recorded: 356
#
# 2011-03-15    572
# 2011-03-17    558
# 2013-02-03    546
# 2011-03-14    520
# 2011-03-16    513
# 2011-03-18    497
# 2011-03-19    466
# 2013-02-04    464
# 2013-01-29    459
# 2011-03-04    458
# 2013-02-14    444
# 2013-01-24    435
# 2011-03-05    434
# 2013-02-15    429
# 2013-03-15    428
# 2011-03-11    426
# 2013-01-30    421
# 2013-02-16    418
# 2011-03-23    417
# 2011-03-09    416
# Name: date_recorded, dtype: int64

# %%
print("Count of Unique funders: "+str(len(train_values.funder.unique())))
print()
print(train_values.funder.value_counts().head(10))
# Out:
# Count of Unique funders: 1897
#
# Government Of Tanzania    9084
# Unknown                   3639
# Danida                    3114
# Hesawa                    2202
# Rwssp                     1374
# World Bank                1349
# Kkkt                      1287
# World Vision              1246
# Unicef                    1057
# Tasaf                      877
# Name: funder, dtype: int64

# %%
print("Count of unique installers: "+str(len(train_values.installer.unique())))
train_values.installer.value_counts().head(20)
# Out:
# Count of unique installers: 2144
# DWE                   17402
# Unknown                3658
# Government             1825
# RWE                    1206
# Commu                  1060
# DANIDA                 1050
# KKKT                    898
# Hesawa                  840
# unknown                 778
# TCRS                    707
# Central government      622
# CES                     610
# Community               553
# DANID                   552
# District Council        551
# HESAWA                  539
# LGA                     408
# World vision            408
# WEDECO                  397
# TASAF                   396
# Name: installer, dtype: int64

# %%
train_values.basin.value_counts()
# Out:
# Lake Victoria              10248
# Pangani                     8940
# Rufiji                      7976
# Internal                    7785
# Lake Tanganyika             6432
# Wami / Ruvu                 5987
# Lake Nyasa                  5085
# Ruvuma / Southern Coast     4493
# Lake Rukwa                  2454
# Name: basin, dtype: int64

# %%
train_values.subvillage.value_counts().head(20)
# Out:
# Madukani      508
# Shuleni       506
# Majengo       502
# Kati          373
# Unknown       371
# Mtakuja       262
# Sokoni        232
# M             187
# Muungano      172
# Mbuyuni       164
# Mlimani       152
# Songambele    147
# Msikitini     134
# Miembeni      134
# 1             132
# Kibaoni       114
# Kanisani      111
# I             109
# Mapinduzi     109
# Mjimwema      108
# Name: subvillage, dtype: int64

# %%
train_values.region.value_counts()
# Out:
# Iringa           5294
# Shinyanga        4982
# Mbeya            4639
# Kilimanjaro      4379
# Morogoro         4006
# Arusha           3350
# Kagera           3316
# Mwanza           3102
# Kigoma           2816
# Ruvuma           2640
# Pwani            2635
# Tanga            2547
# Dodoma           2201
# Singida          2093
# Mara             1969
# Tabora           1959
# Rukwa            1808
# Mtwara           1730
# Manyara          1583
# Lindi            1546
# Dar es Salaam     805
# Name: region, dtype: int64

# %%
train_values[['region','region_code']].sample(10)
# Out:
#               region region_code
# 31981         Arusha           2
# 54608         Ruvuma          10
# 48229         Arusha           2
# 25494          Lindi          80
# 2241     Kilimanjaro           3
# 8992   Dar es Salaam           7
# 1305          Arusha           2
# 31819    Kilimanjaro           3
# 526           Mtwara           9
# 36173      Shinyanga          17

# %%
train_values[['region','region_code']].apply(pd.Series.value_counts)
# Out:
#                region  region_code
# 1                 NaN       2201.0
# 2                 NaN       3024.0
# 3                 NaN       4379.0
# 4                 NaN       2513.0
# 5                 NaN       4040.0
# 6                 NaN       1609.0
# 7                 NaN        805.0
# 8                 NaN        300.0
# 9                 NaN        390.0
# 10                NaN       2640.0
# 11                NaN       5300.0
# 12                NaN       4639.0
# 13                NaN       2093.0
# 14                NaN       1979.0
# 15                NaN       1808.0
# 16                NaN       2816.0
# 17                NaN       5011.0
# 18                NaN       3324.0
# 19                NaN       3047.0
# 20                NaN       1969.0
# 21                NaN       1583.0
# 24                NaN        326.0
# 40                NaN          1.0
# 60                NaN       1025.0
# 80                NaN       1238.0
# 90                NaN        917.0
# 99                NaN        423.0
# Arusha         3350.0          NaN
# Dar es Salaam   805.0          NaN
# Dodoma         2201.0          NaN
# Iringa         5294.0          NaN
# Kagera         3316.0          NaN
# Kigoma         2816.0          NaN
# Kilimanjaro    4379.0          NaN
# Lindi          1546.0          NaN
# Manyara        1583.0          NaN
# Mara           1969.0          NaN
# Mbeya          4639.0          NaN
# Morogoro       4006.0          NaN
# Mtwara         1730.0          NaN
# Mwanza         3102.0          NaN
# Pwani          2635.0          NaN
# Rukwa          1808.0          NaN
# Ruvuma         2640.0          NaN
# Shinyanga      4982.0          NaN
# Singida        2093.0          NaN
# Tabora         1959.0          NaN
# Tanga          2547.0          NaN

# %% [markdown]
# ### Question: should I remove region code? Does region code gives me extra information region doesn't?

# %%
train_values['district_code'].unique()
# Out:
# array([5, 2, 4, 63, 1, 8, 3, 6, 43, 7, 23, 33, 53, 62, 60, 30, 13, 0, 80,
#        67], dtype=object)

# %%
train_values[['region_code','district_code']].apply(pd.Series.value_counts)
# Out:
#     region_code  district_code
# 0           NaN           23.0
# 1        2201.0        12203.0
# 2        3024.0        11173.0
# 3        4379.0         9998.0
# 4        2513.0         8999.0
# 5        4040.0         4356.0
# 6        1609.0         4074.0
# 7         805.0         3343.0
# 8         300.0         1043.0
# 9         390.0            NaN
# 10       2640.0            NaN
# 11       5300.0            NaN
# 12       4639.0            NaN
# 13       2093.0          391.0
# 14       1979.0            NaN
# 15       1808.0            NaN
# 16       2816.0            NaN
# 17       5011.0            NaN
# 18       3324.0            NaN
# 19       3047.0            NaN
# 20       1969.0            NaN
# 21       1583.0            NaN
# 23          NaN          293.0
# 24        326.0            NaN
# 30          NaN          995.0
# 33          NaN          874.0
# 40          1.0            NaN
# 43          NaN          505.0
# 53          NaN          745.0
# 60       1025.0           63.0
# 62          NaN          109.0
# 63          NaN          195.0
# 67          NaN            6.0
# 80       1238.0           12.0
# 90        917.0            NaN
# 99        423.0            NaN

# %% [markdown]
# 'district_code' and 'region_code' doesn't seem to be redundant against each other.

# %%
print(len(train_values['lga'].unique()))
train_values['lga'].unique()
# Out:
# 125
# array(['Ludewa', 'Serengeti', 'Simanjiro', 'Nanyumbu', 'Karagwe',
#        'Mkinga', 'Shinyanga Rural', 'Kahama', 'Tabora Urban', 'Mkuranga',
#        'Namtumbo', 'Maswa', 'Siha', 'Meatu', 'Sumbawanga Rural', 'Njombe',
#        'Ukerewe', 'Bariadi', 'Same', 'Kigoma Rural', 'Moshi Rural',
#        'Lindi Rural', 'Rombo', 'Chamwino', 'Bagamoyo', 'Mafia',
#        'Arusha Rural', 'Kyela', 'Kondoa', 'Kilolo', 'Kibondo', 'Makete',
#        'Singida Rural', 'Masasi', 'Rungwe', 'Moshi Urban', 'Geita',
#        'Mbulu', 'Bukoba Rural', 'Muheza', 'Lushoto', 'Meru', 'Iramba',
#        'Kilombero', 'Mbarali', 'Kasulu', 'Bukoba Urban', 'Korogwe',
#        'Bukombe', 'Morogoro Rural', 'Kishapu', 'Musoma Rural',
#        'Sengerema', 'Iringa Rural', 'Muleba', 'Dodoma Urban', 'Ruangwa',
#        'Hanang', 'Misenyi', 'Missungwi', 'Songea Rural', 'Tanga',
#        'Tunduru', 'Hai', 'Mwanga', 'Chato', 'Biharamulo', 'Ileje',
#        'Mpwapwa', 'Mvomero', 'Bunda', 'Kiteto', 'Longido', 'Urambo',
#        'Mbozi', 'Sikonge', 'Ilala', 'Tarime', 'Temeke', 'Mbeya Rural',
#        'Magu', 'Manyoni', 'Igunga', 'Kilosa', 'Babati', 'Chunya',
#        'Mufindi', 'Mtwara Rural', 'Ngara', 'Karatu', 'Mpanda', 'Kibaha',
#        'Singida Urban', 'Newala', 'Nzega', 'Nkasi', 'Bahi', 'Mbinga',
#        'Ulanga', 'Sumbawanga Urban', 'Morogoro Urban', 'Tandahimba',
#        'Kisarawe', 'Mtwara Urban', 'Kilwa', 'Liwale', 'Kongwa', 'Uyui',
#        'Rufiji', 'Kwimba', 'Monduli', 'Shinyanga Urban', 'Ngorongoro',
#        'Handeni', 'Rorya', 'Pangani', 'Lindi Urban', 'Nachingwea',
#        'Kinondoni', 'Kigoma Urban', 'Ilemela', 'Kilindi', 'Arusha Urban',
#        'Songea Urban', 'Nyamagana'], dtype=object)

# %%
train_values.district_code.unique()
# Out:
# array([5, 2, 4, 63, 1, 8, 3, 6, 43, 7, 23, 33, 53, 62, 60, 30, 13, 0, 80,
#        67], dtype=object)

# %%
train_values[['lga','ward','region','subvillage']].sample(10)
# Out:
#                 lga          ward     region       subvillage
# 46021          Meru      Nkoanrua     Arusha          Moivaro
# 3173          Ileje         Mbebe      Mbeya           Ndendo
# 46117        Njombe      Imalinyi     Iringa            Itula
# 40832       Tunduru       Marumba     Ruvuma         Jiungeni
# 27903       Bukombe         Uyovu  Shinyanga         Kabuhima
# 47090        Ulanga  Kilosa Mpepo   Morogoro    Ihowanja Kati
# 54243     Serengeti     Rung'bure       Mara          Kwanina
# 14101  Arusha Rural       Nduruma     Arusha     Nduruma Kati
# 48767  Kigoma Rural       Nguruka     Kigoma  Nyangabo Kusini
# 53061        Mkinga       Maramba      Tanga            Shule

# %%
len(train_values.ward.unique())
# Out:
# 2092

# %%
train_values.ward.value_counts().head(20)
# Out:
# Igosi            307
# Imalinyi         252
# Siha Kati        232
# Mdandu           231
# Nduruma          217
# Mishamo          203
# Kitunda          203
# Msindo           201
# Chalinze         196
# Maji ya Chai     190
# Usuka            187
# Ngarenanyuki     172
# Chanika          171
# Vikindu          162
# Mtwango          153
# Matola           145
# Zinga/Ikerege    141
# Wanging'ombe     139
# Maramba          139
# Itete            137
# Name: ward, dtype: int64

# %% [markdown]
# ### Do I need all the geographical information or just 'gps_height','longtitude' and 'latitude' features?

# %%
Column with same data: GeoData Consultants Ltd. 
Waterpoint name. 
Not useful.

# %%
print(train_values.recorded_by.value_counts())
train_values.drop('recorded_by',inplace=True,axis=1)
train_values.drop('wpt_name',inplace=True,axis=1)
# Out:
# GeoData Consultants Ltd    59400
# Name: recorded_by, dtype: int64

# %%
train_values[['scheme_management']].apply(pd.Series.value_counts)
# Out:
#                   scheme_management
# VWC                           36793
# WUG                            5206
# Unknown                        3877
# Water authority                3153
# WUA                            2883
# Water Board                    2748
# Parastatal                     1680
# Private operator               1063
# Company                        1061
# Other                           766
# SWC                              97
# Trust                            72
# None                              1

# %%
train_values.scheme_name.value_counts().head(20)
# Out:
# Unknown                                  28166
# K                                          682
# None                                       644
# Borehole                                   546
# Chalinze wate                              405
# M                                          400
# DANIDA                                     379
# Government                                 320
# Ngana water supplied scheme                270
# wanging'ombe water supply s                261
# wanging'ombe supply scheme                 234
# I                                          229
# Bagamoyo wate                              229
# Uroki-Bomang'ombe water sup                209
# N                                          204
# Kirua kahe gravity water supply trust      193
# Machumba estate pipe line                  185
# Makwale water supplied sche                166
# Kijiji                                     161
# S                                          154
# Name: scheme_name, dtype: int64

# %% [markdown]
# train_values.permit.value_counts(())

# %%
t = train_values.construction_year.unique()
pd.Series(t).sort_values().values
# Out:
# array([0, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969,
#        1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013],
#       dtype=object)

# %%
train_values[['extraction_type','extraction_type_group','extraction_type_class']].apply(pd.Series.value_counts)
# Out:
#                            extraction_type  extraction_type_group  \
# afridev                             1770.0                 1770.0
# cemo                                  90.0                    NaN
# climax                                32.0                    NaN
# gravity                            26780.0                26780.0
# handpump                               NaN                    NaN
# india mark ii                       2400.0                 2400.0
# india mark iii                        98.0                   98.0
# ksb                                 1415.0                    NaN
# mono                                2865.0                 2865.0
# motorpump                              NaN                    NaN
# nira/tanira                         8154.0                 8154.0
# other                               6430.0                 6430.0
# other - mkulima/shinyanga              2.0                    NaN
# other - play pump                     85.0                    NaN
# other - rope pump                    451.0                    NaN
# other - swn 81                       229.0                    NaN
# other handpump                         NaN                  364.0
# other motorpump                        NaN                  122.0
# rope pump                              NaN                  451.0
# submersible                         4764.0                 6179.0
# swn 80                              3670.0                 3670.0
# walimi                                48.0                    NaN
# wind-powered                           NaN                  117.0
# windmill                             117.0                    NaN
#
#                            extraction_type_class
# afridev                                      NaN
# cemo                                         NaN
# climax                                       NaN
# gravity                                  26780.0
# handpump                                 16456.0
# india mark ii                                NaN
# india mark iii                               NaN
# ksb                                          NaN
# mono                                         NaN
# motorpump                                 2987.0
# nira/tanira                                  NaN
# other                                     6430.0
# other - mkulima/shinyanga                    NaN
# other - play pump                            NaN
# other - rope pump                            NaN
# other - swn 81                               NaN
# other handpump                               NaN
# other motorpump                              NaN
# rope pump                                  451.0
# submersible                               6179.0
# swn 80                                       NaN
# walimi                                       NaN
# wind-powered                               117.0
# windmill                                     NaN

# %%
print(train_values[(train_values.extraction_type == 'afridev') & (train_values.extraction_type_group== 'afridev')].shape[0])
print(train_values[(train_values.extraction_type == 'gravity') & (train_values.extraction_type_group== 'gravity') & (train_values.extraction_type_class== 'gravity')].shape[0])
print(train_values[(train_values.extraction_type == 'india mark ii') & (train_values.extraction_type_group== 'india mark ii')].shape[0])
print(train_values[(train_values.extraction_type == 'india mark iii') & (train_values.extraction_type_group== 'india mark iii')].shape[0])
print(train_values[(train_values.extraction_type == 'mono') & (train_values.extraction_type_group== 'mono')].shape[0])
print(train_values[(train_values.extraction_type == 'nira/tanira') & (train_values.extraction_type_group== 'nira/tanira')].shape[0])
print(train_values[(train_values.extraction_type == 'other') & (train_values.extraction_type_group== 'other') & (train_values.extraction_type_class== 'other')].shape[0])
print(train_values[(train_values.extraction_type_group== 'submersible') & (train_values.extraction_type_class== 'submersible')].shape[0])
print(train_values[(train_values.extraction_type == 'swn 80') & (train_values.extraction_type_group== 'swn 80')].shape[0])
print(train_values[(train_values.extraction_type == 'windmill') & (train_values.extraction_type_group== 'wind-powered') & (train_values.extraction_type_class== 'wind-powered')].shape[0])
# Out:
# 1770
# 26780
# 2400
# 98
# 2865
# 8154
# 6430
# 6179
# 3670
# 117

# %% [markdown]
# The numbers from the previous cell coinsides with the previous previous cell.

# %% [markdown]
# Handpumps and other handpumps:

# %%
print(len(train_values[train_values.extraction_type_class == "handpump"]))
print()
train_values[train_values.extraction_type_class == "handpump"][['extraction_type','extraction_type_group','extraction_type_class']].value_counts()
# Out:
# 16456
# extraction_type            extraction_type_group  extraction_type_class
# nira/tanira                nira/tanira            handpump                 8154
# swn 80                     swn 80                 handpump                 3670
# india mark ii              india mark ii          handpump                 2400
# afridev                    afridev                handpump                 1770
# other - swn 81             other handpump         handpump                  229
# india mark iii             india mark iii         handpump                   98
# other - play pump          other handpump         handpump                   85
# walimi                     other handpump         handpump                   48
# other - mkulima/shinyanga  other handpump         handpump                    2
# dtype: int64

# %%
print(len(train_values[train_values.extraction_type_group == "other handpump"]))

train_values[train_values.extraction_type_group == "other handpump"][['extraction_type','extraction_type_group','extraction_type_class']].value_counts()
# Out:
# 364
# extraction_type            extraction_type_group  extraction_type_class
# other - swn 81             other handpump         handpump                 229
# other - play pump          other handpump         handpump                  85
# walimi                     other handpump         handpump                  48
# other - mkulima/shinyanga  other handpump         handpump                   2
# dtype: int64

# %% [markdown]
# Motorpumps and other motorpumps:

# %%
print(len(train_values[train_values.extraction_type_group == "other motorpump"]))
train_values[train_values.extraction_type_group == "other motorpump"][['extraction_type','extraction_type_group','extraction_type_class']].value_counts()
# Out:
# extraction_type  extraction_type_group  extraction_type_class
# mono             mono                   motorpump                2865
# cemo             other motorpump        motorpump                  90
# climax           other motorpump        motorpump                  32
# dtype: int64
# extraction_type  extraction_type_group  extraction_type_class
# cemo             other motorpump        motorpump                90
# climax           other motorpump        motorpump                32
# dtype: int64

# %% [markdown]
# 'extraction_type_group' seems to be redundant so it is dropped.
#
# ### The ceveat is that I did not check as throughly as some of the other columns as I have done in the next few cells.

# %%
train_values.drop('extraction_type_group', inplace=True, axis=1)

# %%
print(train_values[['management','management_group']].apply(pd.Series.value_counts))
train_values[['management','management_group']].sample(10)
# Out:
#                   management  management_group
# commercial               NaN            3638.0
# company                685.0               NaN
# other                  844.0             943.0
# other - school          99.0               NaN
# parastatal            1768.0            1768.0
# private operator      1971.0               NaN
# trust                   78.0               NaN
# unknown                561.0             561.0
# user-group               NaN           52490.0
# vwc                  40507.0               NaN
# water authority        904.0               NaN
# water board           2933.0               NaN
# wua                   2535.0               NaN
# wug                   6515.0               NaN
#        management management_group
# 43849         vwc       user-group
# 22167  parastatal       parastatal
# 9266          vwc       user-group
# 18377         vwc       user-group
# 16373         wug       user-group
# 18194         vwc       user-group
# 21515         vwc       user-group
# 4400          vwc       user-group
# 11902         vwc       user-group
# 41022         vwc       user-group

# %%
train_values[['payment','payment_type']].apply(pd.Series.value_counts)
# Out:
#                        payment  payment_type
# annually                   NaN        3642.0
# monthly                    NaN        8300.0
# never pay              25348.0       25348.0
# on failure                 NaN        3914.0
# other                   1054.0        1054.0
# pay annually            3642.0           NaN
# pay monthly             8300.0           NaN
# pay per bucket          8985.0           NaN
# pay when scheme fails   3914.0           NaN
# per bucket                 NaN        8985.0
# unknown                 8157.0        8157.0

# %%
print("Row counts that has both mentioned strings in their respective columns:")
print(train_values[(train_values.payment == 'pay monthly') & (train_values.payment_type == 'monthly')].shape[0])
print(train_values[(train_values.payment == 'pay annually') & (train_values.payment_type == 'annually')].shape[0])
print(train_values[(train_values.payment == 'pay per bucket') & (train_values.payment_type == 'per bucket')].shape[0])
print(train_values[(train_values.payment == 'pay when scheme fails') & (train_values.payment_type == 'on failure')].shape[0])
# Out:
# Row counts that has both mentioned strings in their respective columns:
# 8300
# 3642
# 8985
# 3914

# %% [markdown]
# From the cell above certain string pairs has the same meaning and row count coninsiding with both strings' value_counts from the previous cells.
# Eg: both 'pay monthly' and 'monthly' has the same counts.
#
# There other strings with same counts in both 'payment' and 'payment_type'.
#
# So one of the columns is redundant and seeing 'payment' column and the unique strings, it make less sense than 'payment types' and their unique strings.
#
# So I will drop 'payment'

# %%
train_values.drop('payment',inplace=True,axis=1)

# %%
print(train_values[['water_quality','quality_group']].apply(pd.Series.value_counts))
# Out:
#                     water_quality  quality_group
# colored                       NaN          490.0
# coloured                    490.0            NaN
# fluoride                    200.0          217.0
# fluoride abandoned           17.0            NaN
# good                          NaN        50818.0
# milky                       804.0          804.0
# salty                      4856.0         5195.0
# salty abandoned             339.0            NaN
# soft                      50818.0            NaN
# unknown                    1876.0         1876.0

# %%
print("Row counts that has the mentioned strings in their respective columns:")
print(train_values[(train_values.water_quality == 'coloured') & (train_values.quality_group == 'colored')].shape[0])
print(train_values[((train_values.water_quality == 'fluoride') | (train_values.water_quality == 'fluoride abandoned')) & (train_values.quality_group == 'fluoride')].shape[0])
print(train_values[(train_values.water_quality == 'soft') & (train_values.quality_group == 'good')].shape[0])
print(train_values[((train_values.water_quality == 'salty') | (train_values.water_quality == 'salty abandoned')) & (train_values.quality_group == 'salty')].shape[0])
# Out:
# Row counts that has the mentioned strings in their respective columns:
# 490
# 217
# 50818
# 5195

# %% [markdown]
# For 'water_quality' and 'quality_group' similar deduction can be made here just like 'payment' and 'payment_type' case.
#
# 'water_quality' gives more description than 'quality_group'
# So I will drop 'quality_group'

# %%
train_values.drop('quality_group',inplace=True,axis=1)

# %%
print(train_values[['quantity','quantity_group']].apply(pd.Series.value_counts))
train_values[train_values.quantity == train_values.quantity_group].loc[:,'quantity'].count()
# Out:
#               quantity  quantity_group
# enough           33186           33186
# insufficient     15129           15129
# dry               6246            6246
# seasonal          4050            4050
# unknown            789             789
# 59400

# %%
print("Row counts that has the mentioned strings in their respective columns:")
print(train_values[(train_values.quantity == 'enough') & (train_values.quantity_group == 'enough')].shape[0])
print(train_values[(train_values.quantity == 'insufficient') & (train_values.quantity_group == 'insufficient')].shape[0])
print(train_values[(train_values.quantity == 'dry') & (train_values.quantity_group == 'dry')].shape[0])
print(train_values[(train_values.quantity == 'seasonal') & (train_values.quantity_group == 'seasonal')].shape[0])
print(train_values[(train_values.quantity == 'unknown') & (train_values.quantity_group == 'unknown')].shape[0])
# Out:
# Row counts that has the mentioned strings in their respective columns:
# 33186
# 15129
# 6246
# 4050
# 789

# %% [markdown]
# For 'quantity' and 'quantity_group' similar deduction can be made here just like 'payment' and 'payment_type' case.

# %%
train_values.drop('quantity_group',inplace=True,axis=1)

# %%
train_values[['source','source_type','source_class']].apply(pd.Series.value_counts)
# Out:
#                        source  source_type  source_class
# borehole                  NaN      11949.0           NaN
# dam                     656.0        656.0           NaN
# groundwater               NaN          NaN       45794.0
# hand dtw                874.0          NaN           NaN
# lake                    765.0          NaN           NaN
# machine dbh           11075.0          NaN           NaN
# other                   212.0        278.0           NaN
# rainwater harvesting   2295.0       2295.0           NaN
# river                  9612.0          NaN           NaN
# river/lake                NaN      10377.0           NaN
# shallow well          16824.0      16824.0           NaN
# spring                17021.0      17021.0           NaN
# surface                   NaN          NaN       13328.0
# unknown                  66.0          NaN         278.0

# %%
print(train_values[(train_values.source == 'dam') & (train_values.source_type == 'dam')].shape[0])
print(train_values[(train_values.source == 'rainwater harvesting') & (train_values.source_type == 'rainwater harvesting')].shape[0])
print(train_values[(train_values.source == 'shallow well') & (train_values.source_type == 'shallow well')].shape[0])
print(train_values[(train_values.source == 'spring') & (train_values.source_type == 'spring')].shape[0])
print(train_values[((train_values.source == 'lake') | (train_values.source == 'river')) & (train_values.source_type == 'river/lake')].shape[0])
print(train_values[((train_values.source == 'unknown') | (train_values.source == 'other')) & (train_values.source_type == 'other')].shape[0])



print(train_values[((train_values.source == 'hand dtw') | (train_values.source == 'machine dbh')) & (train_values.source_type == 'borehole')].shape[0])
# Out:
# 656
# 2295
# 16824
# 17021
# 10377
# 278
# 11949

# %%
print(train_values[(train_values.source_type == 'borehole')][['source','source_type','source_class']].sample(10))
# Out:
#             source source_type source_class
# 25261  machine dbh    borehole  groundwater
# 11548  machine dbh    borehole  groundwater
# 15170  machine dbh    borehole  groundwater
# 24515  machine dbh    borehole  groundwater
# 3643   machine dbh    borehole  groundwater
# 7295   machine dbh    borehole  groundwater
# 40499  machine dbh    borehole  groundwater
# 22703  machine dbh    borehole  groundwater
# 57344  machine dbh    borehole  groundwater
# 21756  machine dbh    borehole  groundwater

# %% [markdown]
# These attributes above shows strong "bijectiveness".
# Source_type will be removed.

# %%
train_values.drop('source_type',inplace=True,axis=1)

# %%
train_values[['waterpoint_type','waterpoint_type_group']].apply(pd.Series.value_counts)
# Out:
#                              waterpoint_type  waterpoint_type_group
# cattle trough                            116                  116.0
# communal standpipe                     28522                34625.0
# communal standpipe multiple             6103                    NaN
# dam                                        7                    7.0
# hand pump                              17488                17488.0
# improved spring                          784                  784.0
# other                                   6380                 6380.0

# %%
print(train_values[(train_values.waterpoint_type == 'cattle trough') & (train_values.waterpoint_type_group == 'cattle trough')].shape[0])
print(train_values[((train_values.waterpoint_type == 'communal standpipe') | (train_values.waterpoint_type == 'communal standpipe multiple')) & (train_values.waterpoint_type_group == 'communal standpipe')].shape[0])
print(train_values[(train_values.waterpoint_type == 'dam') & (train_values.waterpoint_type_group == 'dam')].shape[0])
print(train_values[(train_values.waterpoint_type == 'hand pump') & (train_values.waterpoint_type_group == 'hand pump')].shape[0])
print(train_values[(train_values.waterpoint_type == 'improved spring') & (train_values.waterpoint_type_group == 'improved spring')].shape[0])
print(train_values[(train_values.waterpoint_type == 'other') & (train_values.waterpoint_type_group == 'other')].shape[0])
# Out:
# 116
# 34625
# 7
# 17488
# 784
# 6380

# %% [markdown]
# Columns are compared similar to previous cases above.
# I think it is safe to drop waterpoint_type_group while keeps most of the information in place.

# %%
train_values.drop('waterpoint_type_group',inplace=True,axis=1)

# %%
print(train_values.columns)
print("New columns count: "+ str(len(train_values.columns)))
# Out:
# Index(['id', 'amount_tsh', 'date_recorded', 'funder', 'gps_height',
#        'installer', 'longitude', 'latitude', 'num_private', 'basin',
#        'subvillage', 'region', 'region_code', 'district_code', 'lga', 'ward',
#        'population', 'public_meeting', 'scheme_management', 'scheme_name',
#        'permit', 'construction_year', 'extraction_type',
#        'extraction_type_class', 'management', 'management_group',
#        'payment_type', 'water_quality', 'quantity', 'source', 'source_class',
#        'waterpoint_type'],
#       dtype='object')
# New columns count: 32

# %% [markdown]
# # Checking correlations between numerical features

# %%
numerical_variables = [
    "amount_tsh",
    "gps_height",
    "longitude",
    "latitude",
    "region_code",
    "district_code",
    "population",
    "construction_year",
]

# %%
train = train_values.merge(train_labels, on="id")

# %% [markdown]
# -------

# %%
# print(train.columns)
# sns.pairplot(train.sample(1000),kind="scatter")
# commented out the previous line because running all with this line is very slow

sns.heatmap(data=train_values.corr(),vmin=-1, vmax=1, annot=True)
# Out:
# /home/ryan/anaconda3/lib/python3.10/site-packages/seaborn/matrix.py:305: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /home/ryan/anaconda3/lib/python3.10/site-packages/seaborn/matrix.py:305: UserWarning: Attempting to set identical bottom == top == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# <AxesSubplot:>

# %%
sns.pairplot(train,hue='status_group',kind='scatter')

# %% [markdown]
# There is not much useful correlations inbetween the numerical features
#
# Including population and amount of tsh

# %% [markdown]
# ## Question: Does construction year have some correlation with pump status?

# %%
g = train\
    .groupby(by=["construction_year", "status_group"])\
    .size()\
    .reset_index()
g.head()

# plt.plot(g)
# fig,ax = plt.subplot(1,3,1,sharex=True,sharey=True)

# ax.hist(g,range=(1960,g.max()))
# # ax.set()
# plt.show()

# plt.plot(g)
# Out:
#    construction_year             status_group      0
# 0                  0               functional  10555
# 1                  0  functional needs repair   1789
# 2                  0           non functional   8365
# 3               1960               functional     24
# 4               1960  functional needs repair      6

# %%
temp = train[train.construction_year != 0]

# sns.catplot(kind= 'violin',data = temp, y='status_group',x='construction_year')
sns.catplot(kind= 'box',data = temp, y='status_group',x='construction_year')
# sns.catplot(kind='box',data=train, x='date_recorded',y='status_group' )

# %% [markdown]
# # Location based status groups

# %%
grouped_train = train[['lga','status_group']].groupby(['lga','status_group']).value_counts()
idx = pd.IndexSlice
# grouped_train.loc[:,idx(0)]
grouped_train = grouped_train.reset_index()
# grouped_train = grouped_train.iloc[0:62:3,:]
grouped_train
# Out:
#               lga             status_group    0
# 0    Arusha Rural               functional  875
# 1    Arusha Rural  functional needs repair   48
# 2    Arusha Rural           non functional  329
# 3    Arusha Urban               functional   42
# 4    Arusha Urban  functional needs repair    7
# ..            ...                      ...  ...
# 351        Urambo  functional needs repair   14
# 352        Urambo           non functional  213
# 353          Uyui               functional  147
# 354          Uyui  functional needs repair    7
# 355          Uyui           non functional  185
#
# [356 rows x 3 columns]

# %%
coordinates = train[['lga','latitude','longitude']].groupby(['lga']).aggregate(np.mean)

# %%
grouped_train = coordinates.merge(grouped_train,on = 'lga',how='outer',)
grouped_train.rename({'0':'count'},inplace=True)
# grouped_train.drop(['latitude_x'	,'longitude_x'	],axis=1,inplace=True)
# grouped_train.rename({'latitude_y':'latitude',	'longitude_y':'longitude'},axis=1,inplace=True)

# %%
grouped_train
# Out:
#               lga  latitude  longitude             status_group    0
# 0    Arusha Rural -3.360196  36.700034               functional  875
# 1    Arusha Rural -3.360196  36.700034  functional needs repair   48
# 2    Arusha Rural -3.360196  36.700034           non functional  329
# 3    Arusha Urban -3.391063  36.685110               functional   42
# 4    Arusha Urban -3.391063  36.685110  functional needs repair    7
# ..            ...       ...        ...                      ...  ...
# 351        Urambo -4.920823  32.106167  functional needs repair   14
# 352        Urambo -4.920823  32.106167           non functional  213
# 353          Uyui -4.985939  32.831435               functional  147
# 354          Uyui -4.985939  32.831435  functional needs repair    7
# 355          Uyui -4.985939  32.831435           non functional  185
#
# [356 rows x 5 columns]

# %%
f, ax = plt.subplots(figsize=(10, 10))
sns.despine(f, left=True, bottom=True)
plt.xlim(27,43)
# plt.figure(figsize=(400,400))
m = Basemap(resolution='i',llcrnrlat=-12.168,urcrnrlat=-0.967,llcrnrlon=28.828,urcrnrlon=41.177)
# draw coastlines.
m.drawcoastlines()
# draw a boundary around the map, fill the background.
# this background will end up being the ocean color, since
# the continents will be drawn on top.
m.drawmapboundary(fill_color='aqua')
m.drawcountries()
# fill continents, set lake color same as ocean color.
m.fillcontinents(color='coral',lake_color='aqua')
# m.bluemarble()
for index, row in train.iterrows():
    if row.status_group == "functional":
        markercolor="green"
    elif row.status_group == "functional need repair":
        markercolor = "white"
    else:
        markercolor = "black"
    m.plot(row.longitude,
    row.latitude,
    marker="*",
    markersize=4,
    markeredgewidth=0,
    markeredgecolor="white",
    markerfacecolor=markercolor
    )
plt.show()

#                 data=train, ax=ax, hue = "status_group", style="status_group",s=5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [66], line 23
#      21     else:
#      22         markercolor = "black"
# ---> 23     m.plot(row.longitude,
#      24     row.latitude,
#      25     marker="*",
#      26     markersize=4,
#      27     markeredgewidth=0,
#      28     markeredgecolor="white",
#      29     markerfacecolor=markercolor
#      30     )
#      31 plt.show()
#
# File ~/anaconda3/lib/python3.10/site-packages/mpl_toolkits/basemap/__init__.py:569, in _transform1d.<locals>.with_transform(self, x, y, *args, **kwargs)
#     567     # convert lat/lon coords to map projection coords.
#     568     x, y = self(x,y)
# --> 569 return plotfunc(self,x,y,*args,**kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/mpl_toolkits/basemap/__init__.py:3293, in Basemap.plot(self, *args, **kwargs)
#    3291 self._save_use_hold(ax, kwargs)
#    3292 try:
# -> 3293     ret =  ax.plot(*args, **kwargs)
#    3294 finally:
#    3295     self._restore_hold(ax)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:493, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     490     x, y = index_of(xy[-1])
#     492 if self.axes.xaxis is not None:
# --> 493     self.axes.xaxis.update_units(x)
#     494 if self.axes.yaxis is not None:
#     495     self.axes.yaxis.update_units(y)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axis.py:1443, in Axis.update_units(self, data)
#    1437 def update_units(self, data):
#    1438     """
#    1439     Introspect *data* for units converter and update the
#    1440     axis.converter instance if necessary. Return *True*
#    1441     if *data* is registered for unit conversion.
#    1442     """
# -> 1443     converter = munits.registry.get_converter(data)
#    1444     if converter is None:
#    1445         return False
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/units.py:184, in Registry.get_converter(self, x)
#     182 """Get the converter interface instance for *x*, or None."""
#     183 # Unpack in case of e.g. Pandas or xarray object
# --> 184 x = cbook._unpack_to_numpy(x)
#     186 if isinstance(x, np.ndarray):
#     187     # In case x in a masked array, access the underlying data (only its
#     188     # type matters).  If x is a regular ndarray, getdata() just returns
#     189     # the array itself.
#     190     x = np.ma.getdata(x).ravel()
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:2272, in _unpack_to_numpy(x)
#    2268     cls = factory(base_class)
#    2269     return cls.__new__(cls)
# -> 2272 def _unpack_to_numpy(x):
#    2273     """Internal helper to extract data from e.g. pandas and xarray objects."""
#    2274     if isinstance(x, np.ndarray):
#    2275         # If numpy, return directly
#
# KeyboardInterrupt:

# %% [markdown]
# # grouped_train

# %%
f, ax = plt.subplots(figsize=(10, 10))
sns.despine(f, left=True, bottom=True)
plt.xlim(27,43)
# plt.figure(figsize=(400,400))
m = Basemap(resolution='i',llcrnrlat=-12.168,urcrnrlat=-0.967,llcrnrlon=28.828,urcrnrlon=41.177)
# draw coastlines.
m.drawcoastlines()
# draw a boundary around the map, fill the background.
# this background will end up being the ocean color, since
# the continents will be drawn on top.
m.drawmapboundary(fill_color='aqua')
m.drawcountries()
# fill continents, set lake color same as ocean color.
m.fillcontinents(color='coral',lake_color='aqua')
# m.bluemarble()
previous_lga =''
for index, row in grouped_train[grouped_train.status_group=='non functional'].iterrows():
    markercolor = "black"
    
    m.plot(row.longitude,
    row.latitude,
    marker="*",
    markersize=row.count,
    markeredgewidth=0,
    markerfacecolor=markercolor
    )
plt.show()

#                 data=train, ax=ax, hue = "status_group", style="status_group",s=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [365], line 20
#      17 for index, row in grouped_train[grouped_train.status_group=='non functional'].iterrows():
#      18     markercolor = "black"
# ---> 20     m.plot(row.longitude,
#      21     row.latitude,
#      22     marker="*",
#      23     markersize=row.count,
#      24     markeredgewidth=0,
#      25     markerfacecolor=markercolor
#      26     )
#      27 plt.show()
#
# File ~/anaconda3/lib/python3.10/site-packages/mpl_toolkits/basemap/__init__.py:569, in _transform1d.<locals>.with_transform(self, x, y, *args, **kwargs)
#     567     # convert lat/lon coords to map projection coords.
#     568     x, y = self(x,y)
# --> 569 return plotfunc(self,x,y,*args,**kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/mpl_toolkits/basemap/__init__.py:3293, in Basemap.plot(self, *args, **kwargs)
#    3291 self._save_use_hold(ax, kwargs)
#    3292 try:
# -> 3293     ret =  ax.plot(*args, **kwargs)
#    3294 finally:
#    3295     self._restore_hold(ax)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:538, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:538, in <listcomp>(.0)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:531, in <genexpr>(.0)
#     528 else:
#     529     labels = [label] * n_datasets
# --> 531 result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                       {**kwargs, 'label': label})
#     533           for j, label in enumerate(labels))
#     535 if return_kwargs:
#     536     return list(result)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:351, in _process_plot_var_args._makeline(self, x, y, kw, kwargs)
#     349 default_dict = self._getdefaults(set(), kw)
#     350 self._setdefaults(default_dict, kw)
# --> 351 seg = mlines.Line2D(x, y, **kw)
#     352 return seg, kw
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/lines.py:379, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     377 self.set_markevery(markevery)
#     378 self.set_antialiased(antialiased)
# --> 379 self.set_markersize(markersize)
#     381 self._markeredgecolor = None
#     382 self._markeredgewidth = None
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/lines.py:1217, in Line2D.set_markersize(self, sz)
#    1208 def set_markersize(self, sz):
#    1209     """
#    1210     Set the marker size in points.
#    1211
#    (...)
#    1215          Marker size, in points.
#    1216     """
# -> 1217     sz = float(sz)
#    1218     if self._markersize != sz:
#    1219         self.stale = True
#
# TypeError: float() argument must be a string or a real number, not 'method'

# %% [markdown]
# ![screenshot](./screenshot.png)

# %%
sns.histplot(train,x='status_group')
# Out:
# <AxesSubplot:xlabel='status_group', ylabel='Count'>

# %%
sns.catplot(data = train, x = 'gps_height',y = 'status_group',kind='box')

# %% [markdown]
# 'height' has a bit of correlation to 'status_group'? Higher = more functional? But correlation isn't causation.

# %%
f, ax = plt.subplots(figsize=(6.5, 6.5))
ax.set_xlim((0,1000))

sns.boxplot(data = train, x = 'population',y = 'status_group' ,ax=ax)
# Out:
# <AxesSubplot:xlabel='population', ylabel='status_group'>

# %%
selected_variables = [
    'status_group',
    "amount_tsh",
    "gps_height",
    "region_code",
    "district_code",
    "population",
    "construction_year",
]
